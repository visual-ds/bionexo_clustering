# %% [markdown]
# # TF-IDF Vectors

# %% [markdown]
# In this section we will obtain the vectors tf-idf from the most frequent words of our dataset.

# %%
#Import libraries
import pandas as pd
import spacy
import re
import scipy
import unidecode
import warnings
import numpy as np
import sys
import scipy.sparse
import nltk
from nltk import word_tokenize          
from nltk.stem import RSLPStemmer
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Build a Vocabulary

# %% [markdown]
# We now need to create the vocabulary and start the counting process. We can use the CountVectorizer to create a vocabulary from all the text in our dataset followed by the counts of words in the vocabulary.

# %%
#load a set of portugues stopwords (eg, assim , como)
spacy_nlp = spacy.load('pt')
spacy_stopwords = spacy.lang.pt.STOP_WORDS

# %%
#We use a method to reduce a word to its root or to a stem.
class SteamTokenizer(object):
    def __init__(self):
        self.wnl = RSLPStemmer()
    def __call__(self, doc):
        return [self.wnl.stem(t) for t in word_tokenize(doc)]

# %%
#Load dataset
data = pd.read_csv("raw_products.csv",encoding='latin')

# %%
#Dimension of dataset (rows,columns)
data.shape
# Out:
# (674719, 10)

# %%
#First 5 rows of our datset
data.head()
# Out:
#    ID_PDC                               ESPECIALIDADE  \
# 0  174274       SISTEMA GENITAL E REPRODUTOR FEMININO
# 1  176721  SISTEMA MUSCULO-ESQUELETICO E ARTICULAÇÕES
# 2  181909             METODOS DIAGNOSTICOS POR IMAGEM
# 3  183381                  SISTEMA DIGESTIVO E ANEXOS
# 4  183381                  SISTEMA DIGESTIVO E ANEXOS
#
#                               PROCEDIMENTO_PRINCIPAL  \
# 0  HISTERECTOMIA TOTAL LAPAROSCOPICA COM ANEXECTO...
# 1  LESÃO  AGUDA DE LIGAMENTO COLATERAL DO JOELHO ...
# 2  EMBOLIZAÇÃO DE ANEURISMA CEREBRAL POR OCLUSÃO ...
# 3  PANCREATO-DUODENECTOMIA COM LINFADENECTOMIA [ ...
# 4  PANCREATO-DUODENECTOMIA COM LINFADENECTOMIA [ ...
#
#                                 DESCRICAO_DO_PRODUTO       ANVISA  \
# 0                  MANIPULADOR UTERINO CLEARVIEW 7CM  80517980053
# 1  ENXERTO OSSEO EM BLOCO 6 CC 2 X 3 CC ATTRAX PUTTY  80074640024
# 2                         INTRODUTOR 6F 12CM ULTIMUM  10332340107
# 3                                PINÇA LIGA SURE 5MM  10349000188
# 4                    TROCATER DESCARTAVEL 12.5X100MM  80082910071
#
#                   MARCA REFERENCIA    PRECO  \
# 0  CLINICAL INNOVATIONS      UM700     9625
# 1              NUVASIVE    5018006     6875
# 2               ST JUDE     407694     1375
# 3             VALLEYLAB     LS1500  33687.5
# 4  HANGZHOU KANGJI MEDI    101Y524   2062.5
#
#                                           ANVISA_DEF  \
# 0                                                  -
# 1                 attrax putty nuvasive nuvasive inc
# 2                                                  -
# 3                                                  -
# 4  trocarter descartavel hangzhou kangji medical ...
#
#                            GMDN_TERMO
# 0     uterine manipulator, single-use
# 1      bone matrix implant, synthetic
# 2  vascular catheter introduction set
# 3                                   -
# 4                                   -

# %%
#Create a column DOCS. It represents our corpus
data["DOCS"] = data["PROCEDIMENTO_PRINCIPAL"] + " " + data["DESCRICAO_DO_PRODUTO"]

# %%
#Convert to lowercase
data["DOCS"] = data["DOCS"].apply(lambda x : x.lower() )
#remove accents and numbers
data["DOCS"] = data["DOCS"].apply(lambda x : re.sub("[^a-zA-ZÀ-ú']+",' ',x) )
#remove portugues symbols and replace by a normal letter eg. â => a.
data["DOCS"] = data["DOCS"].apply(lambda x : unidecode.unidecode(x) )

# %%
#First 5 rows of our corpus
data["DOCS"].head()
# Out:
# 0    histerectomia total laparoscopica com anexecto...
# 1    lesao aguda de ligamento colateral do joelho t...
# 2    embolizacao de aneurisma cerebral por oclusao ...
# 3    pancreato duodenectomia com linfadenectomia pa...
# 4    pancreato duodenectomia com linfadenectomia pa...
# Name: DOCS, dtype: object

# %%
#Import CountVectorizer to build our vocabulary
from sklearn.feature_extraction.text import CountVectorizer

# %%
#Convert to matrix
docs = data["DOCS"].tolist()

# %%
#create a vocabulary of words, 
#ignore words that appear in 85% of documents, 
#eliminate portugues stop words
#use SteamTokenizer function.
CV = CountVectorizer(max_df=0.85,stop_words=spacy_stopwords,lowercase=True,tokenizer=SteamTokenizer())
#Build vocabulary with our corpus
CV.fit(docs)
# Out:
# CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=0.85, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None,
#         stop_words={'apoia', 'dar', 'desligada', 'todo', 'povo', 'maiorias', 'tentar', 'tens', 'onze', 'enquanto', 'partir', 'quê', 'vão', 'às', 'estar', 'as', 'ligado', 'assim', 'coisa', 'seria', 'valor', 'uma', 'muito', 'após', 'dos', 'neste', 'quer', 'sétimo', 'vos', 'números', 'tuas', 'que', 'oitavo', '...'depois', 'vários', 'tu', 'és', 'nove', 'usa', 'se', 'dá', 'pegar', 'estivemos', 'boa', 'eu', 'põe'},
#         strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#         tokenizer=<__main__.SteamTokenizer object at 0x7f407c804438>,
#         vocabulary=None)

# %%
#Vocabluary
CV.vocabulary_
# Out:
# {'histerectom': 3762,
#  'total': 8081,
#  'laparoscop': 4427,
#  'anexectom': 357,
#  'uni': 8434,
#  'bilater': 866,
#  'uter': 8524,
#  'manipul': 4771,
#  'uterin': 8525,
#  'clearview': 1504,
#  'cm': 1521,
#  'lesa': 4508,
#  'agud': 219,
#  'lig': 4537,
#  'colater': 1578,
#  'joelh': 4294,
#  'trat': 8206,
#  'cirurg': 1455,
#  'reconstruca': 6729,
#  'acl': 86,
#  'titani': 8014,
#  'interferenc': 4110,
#  'x': 8839,
#  'traumed': 8216,
#  'enxert': 2690,
#  'osse': 5690,
#  'bloc': 990,
#  'cc': 1310,
#  'attrax': 646,
#  'putty': 6535,
#  'embolizaca': 2525,
#  'aneurism': 354,
#  'cerebr': 1363,
#  'oclusa': 5535,
#  'sacul': 7084,
#  'vas': 8571,
#  'metod': 4970,
#  'interven': 4137,
#  'terapeu': 7892,
#  'imag': 3908,
#  'introdu': 4194,
#  'f': 3038,
#  'ultimum': 8395,
#  'pancreat': 5802,
#  'duodenectom': 2373,
#  'linfadenectom': 4573,
#  'pancre': 5800,
#  'pinc': 6121,
#  'sur': 7695,
#  'mm': 5122,
#  'trocat': 8287,
#  'descarta': 2106,
#  'simpatectom': 7315,
#  'videotoracoscop': 8701,
#  'nerv': 5364,
#  'perifer': 6008,
#  'dissec': 2258,
#  'ganch': 3365,
#  'angioplast': 372,
#  'translum': 8152,
#  'percutane': 5977,
#  'multipl': 5251,
#  'impl': 3925,
#  'stent': 7574,
#  'hemodinam': 3651,
#  'cardiolog': 1246,
#  'proced': 6373,
#  'fio': 3158,
#  'gui': 3544,
#  'par': 5818,
#  'pt': 6483,
#  'j': 4270,
#  'floppy': 3225,
#  'sistem': 7354,
#  'derivaca': 2091,
#  'ventricul': 8624,
#  'intern': 4127,
#  'valvul': 8547,
#  'reviso': 6922,
#  'encefal': 2553,
#  'kit': 4367,
#  'osv': 5732,
#  'aut': 659,
#  'regula': 6778,
#  'ant': 396,
#  'cam': 1188,
#  'apendicectom': 444,
#  'videolaparoscop': 8698,
#  'intestin': 4143,
#  'grampe': 3497,
#  'echelon': 2432,
#  'articul': 542,
#  'liberaca': 4527,
#  'aderenc': 146,
#  'pelv': 5950,
#  'ressecca': 6845,
#  'cist': 1463,
#  'peritone': 6021,
#  'salpingolis': 7102,
#  'cavidad': 1303,
#  'e': 2418,
#  'pared': 5856,
#  'agulh': 222,
#  'veres': 8637,
#  'mmx': 5133,
#  'irrig': 4240,
#  'aspir': 586,
#  'desfibril': 2121,
#  'plac': 6143,
#  'eletrod': 2483,
#  'marc': 4787,
#  'pass': 5879,
#  'retir': 6875,
#  'pin': 6119,
#  'parafus': 5829,
#  'hast': 3587,
#  'metal': 4960,
#  'intr': 4145,
#  'mater': 4823,
#  'sintes': 7341,
#  'schanz': 7137,
#  'gramp': 3496,
#  'correca': 1814,
#  'deform': 2058,
#  'resolut': 6836,
#  'integrity': 4079,
#  'rx': 7065,
#  'pleurectom': 6172,
#  'pleur': 6171,
#  'catet': 1289,
#  'bloquei': 1002,
#  'endobronqu': 2574,
#  'lobectom': 4621,
#  'hepa': 3672,
#  'esquerd': 2838,
#  'fig': 3142,
#  'via': 8677,
#  'bili': 868,
#  'trocart': 8286,
#  'xcel': 8844,
#  'lamin': 4411,
#  'teso': 7912,
#  'ultracision': 8401,
#  'harmonic': 3584,
#  'at': 612,
#  'line': 4567,
#  'cort': 1819,
#  'cateter': 1290,
#  'cardiac': 1241,
#  'd': 2000,
#  'cineangiocoronariograf': 1432,
#  'ventriculograf': 8627,
#  'diagnost': 2171,
#  'dren': 2338,
#  'multiv': 5263,
#  'alt': 275,
#  'pressa': 6341,
#  'conexa': 1701,
#  'mach': 4708,
#  'feme': 3099,
#  'on': 5582,
#  'off': 5552,
#  'angiograf': 366,
#  'pig': 6107,
#  'fr': 3296,
#  'pleuroscop': 6175,
#  'vide': 8691,
#  'retra': 6884,
#  'incisa': 3958,
#  'rig': 6940,
#  'small': 7391,
#  'colectom': 1586,
#  'parc': 5851,
#  'colostom': 1612,
#  'carg': 1261,
#  'tlc': 8023,
#  'endoscop': 2617,
#  'prostat': 6434,
#  'vesicul': 8667,
#  'bol': 1022,
#  'maquin': 4785,
#  'dupl': 2380,
#  'ch': 1380,
#  'azul': 728,
#  'frat': 3304,
#  'femur': 3104,
#  'cox': 1849,
#  'calibr': 1180,
#  'c': 1152,
#  'nao': 5291,
#  'sele': 7191,
#  'grand': 3499,
#  'angiorradiolog': 374,
#  'angul': 380,
#  'bandej': 767,
#  'microesf': 5015,
#  'embozen': 2534,
#  'microm': 5023,
#  'vermelh': 8638,
#  'ml': 5118,
#  'intracrani': 4156,
#  'parenquem': 5858,
#  'monitorizaca': 5160,
#  'bipol': 960,
#  'forcep': 3268,
#  'endometrios': 2598,
#  'versaport': 8654,
#  'v': 8529,
#  'craniotom': 1882,
#  'descompress': 2113,
#  'crani': 1871,
#  'cab': 1155,
#  'silicon': 7298,
#  'microdissecca': 5012,
#  'luxaco': 4695,
#  'nivel': 5443,
#  'tornozel': 8069,
#  'cortic': 1822,
#  'aco': 89,
#  'esponj': 2827,
#  'rosc': 7001,
#  'matriz': 4832,
#  'regeneraca': 6769,
#  'dural': 2389,
#  'durepa': 2399,
#  'cmx': 1528,
#  'sel': 7188,
#  'fibrin': 3136,
#  'evicel': 2935,
#  'aplic': 452,
#  'luxaca': 4694,
#  'avulsa': 711,
#  'femor': 3102,
#  'articulaca': 544,
#  'hidrofil': 3717,
#  'standart': 7545,
#  'proteca': 6445,
#  'nav': 5306,
#  'emboshied': 2529,
#  'hitorqu': 3767,
#  'versacor': 8648,
#  'pseudartros': 6472,
#  'artros': 566,
#  'fix': 3182,
#  'extern': 3008,
#  'dinam': 2212,
#  'onix': 5588,
#  'prostatavesiculectom': 6435,
#  'radic': 6608,
#  'succa': 7649,
#  'incomep': 3970,
#  'hern': 3683,
#  'disc': 2238,
#  'torac': 8051,
#  'lomb': 4635,
#  'colun': 1625,
#  'vertebr': 8659,
#  'agent': 203,
#  'hemosta': 3663,
#  'colagen': 1574,
#  'absorvi': 43,
#  'heliten': 3624,
#  'g': 3354,
#  'instalaca': 4061,
#  'circuit': 1446,
#  'circulaca': 1448,
#  'extracorpore': 3017,
#  'convenc': 1763,
#  'outr': 5748,
#  'conjunt': 1724,
#  'tub': 8331,
#  'cec': 1325,
#  'adult': 166,
#  'ic': 3860,
#  'ecobec': 2438,
#  'hemoconcentr': 3646,
#  'mediast': 4881,
#  'bomb': 1029,
#  'centrifug': 1351,
#  'centriflux': 1350,
#  'canul': 1210,
#  'aor': 429,
#  'aram': 490,
#  'coronari': 1802,
#  'bala': 749,
#  'concomit': 1683,
#  'omeg': 5571,
#  'anacond': 327,
#  'terum': 7909,
#  'pont': 6258,
#  'ret': 6863,
#  'ultr': 8397,
#  'stiff': 7584,
#  'inoxida': 4043,
#  'revest': 6917,
#  'revascularizaca': 6911,
#  'miocardi': 5096,
#  'coronariopat': 1804,
#  'ma': 4705,
#  'cav': 1299,
#  'cardiopleg': 1253,
#  'colangiopancreatograf': 1577,
#  'retrogr': 6896,
#  'papilotm': 5816,
#  'tripl': 8272,
#  'lumen': 4681,
#  'artroplast': 564,
#  'escapul': 2765,
#  'umer': 8422,
#  'cint': 1439,
#  'arrow': 523,
#  'camis': 1190,
#  'ar': 487,
#  'membr': 4914,
#  'polietersulf': 6230,
#  'flux': 3245,
#  'm': 4704,
#  'retropleg': 6901,
#  'insufl': 4071,
#  'encor': 2560,
#  'advantag': 174,
#  'ext': 2998,
#  'suport': 7682,
#  'choic': 1398,
#  'plu': 6187,
#  'apex': 446,
#  'bicamer': 844,
#  'ger': 3429,
#  'atr': 632,
#  'punca': 6518,
#  'peel': 5939,
#  'away': 713,
#  'dilock': 2205,
#  'frx': 3325,
#  'qualqu': 6572,
#  'tecn': 7838,
#  'versa': 8646,
#  'quadril': 6567,
#  'restri': 6858,
#  'ciment': 1424,
#  'epimiocardi': 2720,
#  'temporari': 7860,
#  'patch': 5886,
#  'pericardi': 6000,
#  'bovin': 1054,
#  'curv': 1972,
#  'ez': 3036,
#  'glid': 3458,
#  'colocaca': 1605,
#  'protes': 6449,
#  'coledoci': 1588,
#  'dilat': 2200,
#  'sbdc': 7126,
#  'st': 7534,
#  'jagw': 4275,
#  'papilot': 5815,
#  'tip': 7988,
#  'fac': 3043,
#  'retencion': 6871,
#  'reforc': 6763,
#  'cruz': 1932,
#  'anteri': 404,
#  'posteri': 6285,
#  'videoartroscop': 8692,
#  'bioscrew': 941,
#  'elevat': 2493,
#  'disposi': 2253,
#  'repar': 6816,
#  'prolaps': 6412,
#  'apic': 447,
#  'fixaca': 3183,
#  'nefrectom': 5332,
#  'unilater': 8452,
#  'rim': 6950,
#  'bacinet': 739,
#  'supr': 7685,
#  'renal': 6806,
#  'sutur': 7726,
#  'sinte': 7339,
#  'verd': 8636,
#  'vloc': 8744,
#  'ureterorrenolitotrips': 8492,
#  'a': 2,
#  'las': 4451,
#  'uret': 8475,
#  'espir': 2818,
#  'nitinol': 5438,
#  'retenca': 6870,
#  'resgat': 6831,
#  'urolog': 8510,
#  'ston': 7591,
#  'con': 1673,
#  'diges': 2193,
#  'biops': 929,
#  'citolog': 1480,
#  'colangi': 1575,
#  'standard': 7544,
#  'contour': 1754,
#  'ureteroscop': 8493,
#  'sensor': 7215,
#  'angiog': 365,
#  'ultimat': 8394,
#  'leso': 4511,
#  'intrinsec': 4192,
#  'condr': 1691,
#  'osteocondrit': 5700,
#  'plic': 6180,
#  'patolog': 5893,
#  'corp': 1806,
#  'livr': 4612,
#  'artrofitos': 561,
#  'shav': 7262,
#  'ba': 731,
#  'nucle': 5479,
#  'ptf': 6492,
#  'cor': 1782,
#  'rio': 6959,
#  'point': 6214,
#  'jl': 4291,
#  'simmom': 7309,
#  'pigtail': 6108,
#  'amplatz': 313,
#  'sup': 7667,
#  'short': 7281,
#  'long': 4640,
#  'tap': 7793,
#  'radiofocu': 6616,
#  'introduc': 4195,
#  'ii': 3883,
#  'tromb': 8291,
#  'mandibul': 4759,
#  'func': 3337,
#  'broc': 1091,
#  'som': 7447,
#  'medic': 4886,
#  'odontolog': 5549,
#  'grau': 3510,
#  'nefrolitotrips': 5334,
#  'mec': 4872,
#  'h': 3560,
#  'us': 8517,
#  'indovasiv': 3984,
#  'compon': 1652,
#  'acetabul': 77,
#  'century': 1355,
#  'modul': 5147,
#  'cimentaca': 1425,
#  'angi': 359,
#  'seal': 7160,
#  'associ': 599,
#  'menisc': 4924,
#  'endobotton': 2572,
#  'espec': 2809,
#  'plas': 6152,
#  'mont': 5178,
#  'flex': 3206,
#  'runway': 7058,
#  'al': 235,
#  'mr': 5211,
#  'eluica': 2514,
#  'everolimu': 2934,
#  'promu': 6420,
#  'element': 2475,
#  'complac': 1645,
#  'quantum': 6574,
#  'sinusectom': 7346,
#  'maxil': 4845,
#  'endonas': 2602,
#  'paranas': 5845,
#  'bleed': 983,
#  'stp': 7598,
#  'gel': 3403,
#  'basket': 791,
#  'extraca': 3014,
#  'calcul': 1176,
#  'insert': 4054,
#  'tib': 7961,
#  'revisa': 6920,
#  'nefrolitotom': 5333,
#  'artrodes': 557,
#  'poster': 6284,
#  'later': 4459,
#  'cervic': 1369,
#  'cercl': 1361,
#  'cb': 1308,
#  'inclu': 3964,
#  'descol': 2112,
#  'epifisari': 2711,
#  'cotovel': 1838,
#  'punh': 6522,
#  'antebrac': 397,
#  'pol': 6215,
#  'gastroplast': 3382,
#  'obes': 5505,
#  'morb': 5183,
#  'estomag': 2887,
#  'osteotom': 5726,
#  'rosq': 7004,
#  'vapr': 8557,
#  'tam': 7780,
#  'sid': 7288,
#  'mastectom': 4814,
#  'subcutane': 7626,
#  'inclusa': 3966,
#  'mam': 4750,
#  'text': 7920,
#  'redond': 6743,
#  'perfil': 5984,
#  'fixation': 3186,
#  'tri': 8241,
#  'stapl': 7546,
#  'rox': 7036,
#  'medi': 4880,
#  'brac': 1063,
#  'retossigmoidectom': 6881,
#  'abdom': 14,
#  'gx': 3556,
#  'circul': 1447,
#  'transrad': 8177,
#  'osteoplast': 5717,
#  'prognat': 6399,
#  'micrognat': 5019,
#  'laterognat': 4460,
#  'cran': 1868,
#  'format': 3272,
#  'l': 4388,
#  'fur': 3342,
#  'rosque': 7006,
#  'cabec': 1156,
#  'diametr': 2183,
#  'comp': 1635,
#  'estabiliz': 2849,
#  'bimaxil': 872,
#  'bloque': 998,
#  'shunt': 7283,
#  'intracardiac': 4147,
#  'assist': 596,
#  'set': 7238,
#  'contrat': 1759,
#  'adrenalectom': 162,
#  'clip': 1513,
#  'hemolok': 3654,
#  'mc': 4858,
#  'end': 2563,
#  'gia': 3436,
#  'univers': 8465,
#  'pielograf': 6093,
#  'orient': 5643,
#  'tc': 7822,
#  'rm': 6967,
#  'colangiograf': 1576,
#  'transcutane': 8116,
#  'reg': 6765,
#  'fx': 3351,
#  'accustick': 65,
#  'oss': 5689,
#  'carp': 1268,
#  'et': 2903,
#  'plug': 6188,
#  'intramedul': 4166,
#  'delt': 2075,
#  'uniqu': 8461,
#  'ua': 8373,
#  'ventilaca': 8618,
#  'pvc': 6540,
#  'perfuraca': 5992,
#  'conec': 1697,
#  'pe': 5917,
#  'plan': 6146,
#  'valg': 8539,
#  'versalock': 8651,
#  'r': 6600,
#  'ven': 8611,
#  'centr': 1346,
#  'npp': 5466,
#  'qt': 6558,
#  'hemodepuraca': 3648,
#  'infusa': 4016,
#  'sor': 7467,
#  'drog': 2348,
#  'acess': 72,
#  'vascul': 8575,
#  'picc': 6088,
#  'per': 5968,
#  'q': 6550,
#  'cath': 1294,
#  'alc': 239,
#  'polipectom': 6237,
#  'oval': 5751,
#  'min': 5076,
#  'frasc': 3303,
#  'gastr': 3375,
#  'drain': 2333,
#  'simon': 7311,
#  'nc': 5318,
#  'sprint': 7518,
#  'laparotom': 4429,
#  'explor': 2992,
#  'abscess': 36,
#  'brid': 1083,
#  'vigenc': 8704,
#  'uretrotom': 8503,
#  'uretr': 8499,
#  'manquit': 4777,
#  'rot': 7009,
#  'hyperform': 3849,
#  'cobr': 1550,
#  'colonoscop': 1607,
#  'retossigmoidoscop': 6882,
#  'artroscop': 568,
#  'diret': 2231,
#  'ureter': 8476,
#  'ligad': 4540,
#  'tireoidectom': 7996,
#  'tireoid': 7994,
#  'nim': 5428,
#  'sond': 7453,
#  'eletroest': 2485,
#  'herniorraf': 3687,
#  'ingu': 4019,
#  'tel': 7848,
#  'polipropilen': 6238,
#  'prolen': 6413,
#  'reperfusa': 6818,
#  'aspiraca': 587,
#  'max': 4836,
#  'microcirurg': 5002,
#  'raney': 6639,
#  'pacot': 5776,
#  'unidad': 8442,
#  'duragen': 2388,
#  'comum': 1670,
#  'pic': 6087,
#  'epid': 2706,
#  'temperat': 7857,
#  'neurodur': 5378,
#  'inox': 4042,
#  'testicul': 7915,
#  'ns': 5470,
#  'med': 4876,
#  'lum': 4678,
#  'permanenc': 6029,
#  'ash': 581,
#  'aplit': 456,
#  'antibio': 410,
#  'lineag': 4568,
#  'gr': 3486,
#  'instrumentaca': 4067,
#  'segment': 7180,
#  'pedicul': 5931,
#  'poliax': 6222,
#  'spherx': 7490,
#  'beir': 815,
#  'leit': 4496,
#  'swan': 7737,
#  'ganz': 3369,
#  'debit': 2029,
#  'continu': 1751,
#  'flotrac': 3228,
#  'ag': 202,
#  'rad': 6605,
#  'jaw': 4281,
#  'fibul': 3139,
#  'pern': 6034,
#  'pba': 5902,
#  's': 7072,
#  'troc': 8281,
#  'rap': 6643,
#  'dilataca': 2201,
#  'cre': 1887,
#  'wireguided': 8825,
#  'tumor': 8342,
#  'micr': 4991,
#  'fres': 3316,
#  'carniot': 1264,
#  'blak': 977,
#  'cilindr': 1422,
#  'compress': 1665,
#  'neurocirurg': 5375,
#  'bio': 874,
#  'spong': 7511,
#  'parenquim': 5859,
#  'tuneliz': 8347,
#  'sophys': 7466,
#  'adheru': 149,
#  'avulso': 712,
#  'fiogu': 3160,
#  'oliv': 5565,
#  'inorgan': 4039,
#  'gen': 3411,
#  'ox': 5754,
#  'inorg': 4038,
#  'hemodialis': 3649,
#  'curt': 1969,
#  'extrem': 3023,
#  'metafis': 4956,
#  'dist': 2264,
#  'fbm': 3086,
#  'radi': 6606,
#  'uln': 8389,
#  'bols': 1027,
#  'hematom': 3631,
#  'impact': 3916,
#  'coxofemor': 1851,
#  'reservatori': 6828,
#  'filtr': 3154,
#  'mp': 5201,
#  'arter': 527,
#  'absorv': 42,
#  'po': 6210,
#  'surgidry': 7710,
#  'valv': 8544,
#  'tec': 7832,
#  'velud': 8609,
#  'optitorqu': 5628,
#  'rc': 6671,
#  'intralum': 4165,
#  'vol': 8753,
#  'fil': 3145,
#  'direit': 2227,
#  'transesfenoid': 8126,
#  'sonic': 7454,
#  'sonoc': 7458,
#  'bas': 785,
#  'hydrogel': 3841,
#  'impermeabilizaca': 3923,
#  'duramat': 2391,
#  'durase': 2394,
#  'clavicul': 1494,
#  'ombr': 5570,
#  'acromioniz': 107,
#  'aort': 431,
#  'infr': 4010,
#  'equaliz': 2734,
#  'endoprotes': 2612,
#  'extensa': 3003,
#  'lc': 4470,
#  'flexi': 3211,
#  'inje': 4024,
#  'escleros': 2771,
#  'variz': 8569,
#  'ram': 6637,
#  'primari': 6359,
#  'y': 8895,
#  'farmacolog': 3070,
#  'plast': 6157,
#  'valvoplast': 8546,
#  'oxigen': 5758,
#  'cpc': 1855,
#  'crc': 1885,
#  'offset': 5554,
#  'tampa': 7785,
#  'interfit': 4111,
#  'reflection': 6758,
#  'lindorf': 4565,
#  'dir': 2222,
#  'pur': 6524,
#  'shaft': 7257,
#  'glidew': 3461,
#  'estud': 2900,
#  'cardiopat': 1250,
#  'congenit': 1714,
#  'valvopat': 8545,
#  'cinecoronariograf': 1436,
#  'oximetr': 5761,
#  'impuls': 3945,
#  'ebu': 2427,
#  'launch': 4463,
#  'ts': 8317,
#  'sang': 7107,
#  'cardiotom': 1255,
#  'pediatr': 5928,
#  'asplas': 591,
#  'camp': 1191,
#  'opsit': 5611,
#  'gram': 3495,
#  'titane': 8011,
#  'eurocon': 2918,
#  'ceram': 1358,
#  'biolox': 908,
#  'fort': 3276,
#  'estimulaca': 2884,
#  'ingevity': 4018,
#  'mri': 5213,
#  'estenostom': 2864,
#  'histeroscop': 3764,
#  'ressectoscopi': 6846,
#  'miomectom': 5099,
#  'metroplast': 4972,
#  'endometrectom': 2596,
#  'sinequ': 7325,
#  'ultrasson': 8413,
#  'coagulaca': 1536,
#  'compr': 1662,
#  'sonosurg': 7461,
#  'extrac': 3013,
#  'remoca': 6800,
#  'pro': 6368,
#  'xl': 8857,
#  'forc': 3267,
#  'intravascul': 4186,
#  'pulmon': 6511,
#  'reduca': 6746,
#  'incruent': 3976,
#  'cest': 1373,
#  'extra': 3012,
#  'segur': 7184,
#  'hemisph': 3641,
#  'kirshin': 4362,
#  'falang': 3052,
#  'metacarpi': 4950,
#  'mao': 4781,
#  'parcu': 5853,
#  'gf': 3433,
#  'bec': 811,
#  'ablaca': 26,
#  'bipas': 957,
#  'mastoidectom': 4818,
#  'simpl': 7316,
#  'modific': 5145,
#  'orelh': 5639,
#  'contat': 1743,
#  'dermolipectom': 2096,
#  'avent': 699,
#  'export': 2994,
#  'axil': 717,
#  'poplite': 6260,
#  'vxt': 8784,
#  'wall': 8789,
#  'interfalange': 4105,
#  'light': 4548,
#  'ortoped': 5676,
#  'membrana': 4915,
#  'vacu': 8532,
#  'labr': 4395,
#  'microdebridaca': 5007,
#  'inc': 3952,
#  'jr': 4306,
#  'incis': 3957,
#  'ster': 7577,
#  'drap': 2334,
#  'sonicision': 7456,
#  'chav': 1388,
#  'torqu': 8074,
#  'hallux': 3570,
#  'valgu': 8540,
#  'fend': 3106,
#  'eletrofisiolog': 2488,
#  'mape': 4782,
#  'eletr': 2476,
#  'eletron': 2490,
#  'tridimens': 8250,
#  'conduca': 1694,
#  'aca': 48,
#  'steerocath': 7567,
#  'dx': 2405,
#  'radifocu': 6611,
#  'focu': 3254,
#  'gastrectom': 3376,
#  'seri': 7230,
#  'eea': 2454,
#  'dst': 2356,
#  'operatori': 5603,
#  'drenoplas': 2340,
#  'etmo': 2909,
#  'orbit': 5636,
#  'etmoid': 2910,
#  'traum': 8212,
#  'maxdriv': 4840,
#  'acraclip': 97,
#  'lightwav': 4549,
#  'segmentectom': 7182,
#  'pulma': 6510,
#  'recarg': 6709,
#  'dour': 2322,
#  'esf': 2781,
#  'mtp': 5221,
#  'gastrostom': 3384,
#  'botton': 1051,
#  'alimentaca': 253,
#  'enter': 2662,
#  'mic': 4989,
#  'key': 4340,
#  'psi': 6477,
#  'dtt': 2360,
#  'tl': 8021,
#  'arruel': 524,
#  'dent': 2082,
#  'lf': 4517,
#  'monoax': 5163,
#  'rotur': 7028,
#  'desinserca': 2130,
#  'arranc': 512,
#  'capsul': 1219,
#  'ten': 7862,
#  'ligament': 4542,
#  'anc': 336,
#  'distraca': 2271,
#  'catch': 1287,
#  'ligasur': 4546,
#  'maryland': 4809,
#  'bainh': 746,
#  'port': 6270,
#  'interlock': 4116,
#  'idc': 3870,
#  'fibr': 3131,
#  'medikit': 4890,
#  'highflex': 3729,
#  'tenotom': 7887,
#  'tendo': 7871,
#  'burs': 1141,
#  'sinov': 7334,
#  'acc': 51,
#  'coarctaca': 1540,
#  'defeit': 2047,
#  'estagi': 2852,
#  'art': 525,
#  'pam': 5798,
#  'trapezoid': 8196,
#  'polietilen': 6231,
#  'rev': 6910,
#  'profemur': 6388,
#  'razek': 6664,
#  'puls': 6512,
#  'safi': 7092,
#  'promr': 6419,
#  'marcapass': 4789,
#  'condic': 1686,
#  'ressonanc': 6849,
#  'magne': 4728,
#  'etrins': 2913,
#  'dr': 2330,
#  't': 7765,
#  'punch': 6520,
#  'trilogy': 8264,
#  'driv': 2347,
#  'pre': 6311,
#  'bent': 822,
#  'ap': 435,
#  'ti': 7958,
#  'cros': 1912,
#  'cefal': 1326,
#  'col': 1572,
#  'optilit': 5622,
#  'u': 8372,
#  'uso': 8521,
#  'unic': 8437,
#  'lis': 4596,
#  'im': 3905,
#  'lotu': 4655,
#  'lac': 4397,
#  'sn': 7407,
#  'prelud': 6325,
#  'colecistectom': 1582,
#  'capac': 1213,
#  'trabalh': 8092,
#  'ench': 2557,
#  'confecca': 1704,
#  'fistul': 3173,
#  'av': 691,
#  'fin': 3155,
#  'endoscopi': 2618,
#  'osteocondroplast': 5701,
#  'estabilizaca': 2850,
#  'acromioplast': 108,
#  'bur': 1138,
#  'decapol': 2038,
#  'cartuch': 1278,
#  'evercros': 2930,
#  'retard': 6868,
#  'consolidaca': 1732,
#  'perd': 5979,
#  'conic': 1717,
#  'marlex': 4798,
#  'biolog': 907,
#  'intraor': 4174,
#  'p': 5769,
#  'serr': 7232,
#  'reciproc': 6717,
#  'soehendr': 7419,
#  'meniscectom': 4925,
#  'arthrocut': 536,
#  'full': 3334,
#  'ref': 6753,
#  'smith': 7401,
#  'nephew': 5359,
#  'bioabsorvi': 877,
#  'hidroxiapatit': 3725,
#  'conserv': 1729,
#  'bloq': 995,
#  'vital': 8729,
#  'ls': 4665,
#  'pequen': 5966,
#  'monocamer': 5165,
#  'instrument': 4066,
#  'esofag': 2795,
#  'duoden': 2372,
#  'sering': 7231,
#  'insuflaca': 4072,
#  'especific': 2811,
#  ...}

# %%
#Size of vocabulary
len(CV.vocabulary_)
# Out:
# 8945

# %%
#Remove words less than 3 words
vocabulary = CV.vocabulary_.copy()
for key,value in vocabulary.items():
    if len(key) <= 3 :
        del CV.vocabulary_[key]

# %%
len(CV.vocabulary_)
# Out:
# 7370

# %%
# TF vectors
tf_vectors = CV.transform(docs)

# %%
# (number samples,vocabulary)
tf_vectors.shape
# Out:
# (674719, 7370)

# %% [markdown]
# ## TF-IDF Vectors

# %% [markdown]
# We will create tf-idf vectors, we are essentially taking the sparse matrix from CountVectorizer (word_count_vector).
# We use TfidfTransformer from sklearn library

# %%
from sklearn.feature_extraction.text import TfidfTransformer

# %%
#Fit model
tfidf_transformer = TfidfTransformer(smooth_idf=True,use_idf=True)
tfidf_transformer.fit(tf_vectors)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-f3de9a57af6f> in <module>()
#       1 #Fit model
# ----> 2 tfidf_transformer = TfidfTransformer(smooth_idf=True,use_idf=True)
#       3 tfidf_transformer.fit(tf_vectors)
#
# NameError: name 'TfidfTransformer' is not defined

# %%
#Get TF-IDF vectors
tf_idf_vector = tfidf_transformer.transform(tf_vectors)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4aa543f16f27> in <module>()
#       1 #Get TF-IDF vectors
# ----> 2 tf_idf_vector = tfidf_transformer.transform(tf_vectors)
#
# NameError: name 'tfidf_transformer' is not defined

# %%
#Size of tf-idf vectors
tf_idf_vector.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-dfe5b3045d83> in <module>()
#       1 #Size of tf-idf vectors
# ----> 2 tf_idf_vector.shape
#
# NameError: name 'tf_idf_vector' is not defined

# %%
#Export vectors to matrix dense format
scipy.sparse.save_npz("tfidf_vectors.npz", tf_idf_vector)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-464c0cc7079b> in <module>()
#       1 #Export vectors to matrix dense format
# ----> 2 scipy.sparse.save_npz("tfidf_vectors.npz", tf_idf_vector)
#
# NameError: name 'scipy' is not defined
